# %%
# Mount ADLS Gen2
# Required each time the cluster is restarted which should be only on the first notebook as they run in order

tiers = ["bronze", "silver", "gold"]
adls_paths = {tier: f"abfss://{tier}@dataluke124.dfs.core.windows.net/" for tier in tiers}

# Accessing paths
bronze_adls = adls_paths["bronze"]
silver_adls = adls_paths["silver"]
gold_adls = adls_paths["gold"] 

dbutils.fs.ls(bronze_adls)
dbutils.fs.ls(silver_adls)
dbutils.fs.ls(gold_adls)
# Out:
# []

# %%
import requests
import json
from datetime import date, timedelta

# %%
start_date = date.today() - timedelta(1)
end_date = date.today()

# %%
start_date, end_date
# Out:
# (datetime.date(2025, 5, 24), datetime.date(2025, 5, 25))

# %%
# Construct the API URL with start and end dates provided by Data Factory, formatted for geojson output.
url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"

# %%
url
# Out:
# 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime=2025-05-24&endtime=2025-05-25'

# %%
try:
    # Make the GET request to fetch data
    response = requests.get(url)

    # Check if the request was successful
    response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)
    data = response.json().get('features', [])

    if not data:
        print("No data returned for the specified date range.")
    else:
        # Specify the ADLS path
        file_path = f"{bronze_adls}/{start_date}_earthquake_data.json"

        # Save the JSON data
        json_data = json.dumps(data, indent=4)
        dbutils.fs.put(file_path, json_data, overwrite=True)
        print(f"Data successfully saved to {file_path}")
except requests.exceptions.RequestException as e:
    print(f"Error fetching data from API: {e}")
# Out:
# Wrote 259667 bytes.
# Data successfully saved to abfss://bronze@dataluke124.dfs.core.windows.net//2025-05-24_earthquake_data.json

# %%
data
# Out:
# [{'type': 'Feature',
#   'properties': {'mag': 1.73,
#    'place': '10 km  of Pittsburg, CA',
#    'time': 1748130484280,
#    'updated': 1748166738755,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75186056',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75186056&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 46,
#    'net': 'nc',
#    'code': '75186056',
#    'ids': ',nc75186056,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 16,
#    'dmin': 0.03164,
#    'rms': 0.13,
#    'gap': 97,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 10 km  of Pittsburg, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.9165, 38.1118333333333, 25.87]},
#   'id': 'nc75186056'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.8,
#    'place': '36 km NE of Crane, Texas',
#    'time': 1748130263805,
#    'updated': 1748130462705,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025kdca',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025kdca&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 50,
#    'net': 'tx',
#    'code': '2025kdca',
#    'ids': ',tx2025kdca,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 41,
#    'dmin': 0,
#    'rms': 0.6,
#    'gap': 107,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 36 km NE of Crane, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-102.079, 31.626, 2.6146]},
#   'id': 'tx2025kdca'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.8,
#    'place': '3 km WSW of Anderson Springs, CA',
#    'time': 1748130048630,
#    'updated': 1748131640997,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75186046',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75186046&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 10,
#    'net': 'nc',
#    'code': '75186046',
#    'ids': ',nc75186046,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 6,
#    'dmin': 0.002425,
#    'rms': 0.03,
#    'gap': 183,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 3 km WSW of Anderson Springs, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.724998474121, 38.7591667175293, 2.32999992370605]},
#   'id': 'nc75186046'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.38,
#    'place': '15 km WSW of Searles Valley, CA',
#    'time': 1748129946980,
#    'updated': 1748130152676,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40975359',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40975359&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 2,
#    'net': 'ci',
#    'code': '40975359',
#    'ids': ',ci40975359,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 11,
#    'dmin': 0.1236,
#    'rms': 0.08,
#    'gap': 110,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.4 - 15 km WSW of Searles Valley, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.5596667, 35.7201667, 2.61]},
#   'id': 'ci40975359'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.7,
#    'place': '31 km NW of Susitna, Alaska',
#    'time': 1748129590094,
#    'updated': 1748129680894,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0256mja1fl',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0256mja1fl&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 8,
#    'net': 'ak',
#    'code': '0256mja1fl',
#    'ids': ',ak0256mja1fl,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.1,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.7 - 31 km NW of Susitna, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-150.8526, 61.7719, 59.1]},
#   'id': 'ak0256mja1fl'},
#  {'type': 'Feature',
#   'properties': {'mag': 2,
#    'place': '3 km S of Alger, Washington',
#    'time': 1748127382020,
#    'updated': 1748155236556,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw62115466',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw62115466&format=geojson',
#    'felt': 1,
#    'cdi': 1,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 62,
#    'net': 'uw',
#    'code': '62115466',
#    'ids': ',uw62115466,',
#    'sources': ',uw,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 32,
#    'dmin': 0.0714,
#    'rms': 0.19,
#    'gap': 42,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.0 - 3 km S of Alger, Washington'},
#   'geometry': {'type': 'Point', 'coordinates': [-122.333, 48.5845, 17.14]},
#   'id': 'uw62115466'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.1,
#    'place': '26 km E of McKinney Acres, Texas',
#    'time': 1748126663423,
#    'updated': 1748126986307,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025kczz',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025kczz&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 19,
#    'net': 'tx',
#    'code': '2025kczz',
#    'ids': ',tx2025kczz,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 16,
#    'dmin': 0.1,
#    'rms': 0.5,
#    'gap': 166,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 26 km E of McKinney Acres, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-102.25, 32.279, 5.8386]},
#   'id': 'tx2025kczz'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.9,
#    'place': '42 km WNW of Beatty, Nevada',
#    'time': 1748126440351,
#    'updated': 1748126575585,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00897948',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00897948&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 12,
#    'net': 'nn',
#    'code': '00897948',
#    'ids': ',nn00897948,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 18,
#    'dmin': 0.168,
#    'rms': 0.2642,
#    'gap': 106.50999999999999,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 42 km WNW of Beatty, Nevada'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.1543, 37.1176, 0.7]},
#   'id': 'nn00897948'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.8,
#    'place': '37 km NNW of Toyah, Texas',
#    'time': 1748126250865,
#    'updated': 1748126421106,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025kczs',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025kczs&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 50,
#    'net': 'tx',
#    'code': '2025kczs',
#    'ids': ',tx2025kczs,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 39,
#    'dmin': 0,
#    'rms': 0.3,
#    'gap': 41,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 37 km NNW of Toyah, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-103.988, 31.612, 4.6801]},
#   'id': 'tx2025kczs'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '20 km NW of Stanton, Texas',
#    'time': 1748125547854,
#    'updated': 1748125857855,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025kczj',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025kczj&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'tx',
#    'code': '2025kczj',
#    'ids': ',tx2025kczj,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 41,
#    'dmin': 0,
#    'rms': 0.5,
#    'gap': 25,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 20 km NW of Stanton, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-101.932, 32.266, 4.2486]},
#   'id': 'tx2025kczj'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.9,
#    'place': '54 km W of Mentone, Texas',
#    'time': 1748124939840,
#    'updated': 1748125120561,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025kcyz',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025kcyz&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 56,
#    'net': 'tx',
#    'code': '2025kcyz',
#    'ids': ',tx2025kcyz,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 34,
#    'dmin': 0.1,
#    'rms': 0.3,
#    'gap': 57,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 54 km W of Mentone, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.178, 31.706, 4.303]},
#   'id': 'tx2025kcyz'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.75,
#    'place': '5 km WNW of Cobb, CA',
#    'time': 1748124003270,
#    'updated': 1748125636213,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75186041',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75186041&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 9,
#    'net': 'nc',
#    'code': '75186041',
#    'ids': ',nc75186041,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 13,
#    'dmin': 0.01153,
#    'rms': 0.02,
#    'gap': 65,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 5 km WNW of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.785499572754, 38.8274993896484, 1.79999995231628]},
#   'id': 'nc75186041'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.1,
#    'place': '36 km WNW of Tyonek, Alaska',
#    'time': 1748123280944,
#    'updated': 1748123381313,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0256mi6d9a',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0256mi6d9a&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 19,
#    'net': 'ak',
#    'code': '0256mi6d9a',
#    'ids': ',ak0256mi6d9a,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.3,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 36 km WNW of Tyonek, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.7629, 61.1879, 79.6]},
#   'id': 'ak0256mi6d9a'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.8,
#    'place': '37 km NNW of Toyah, Texas',
#    'time': 1748123076449,
#    'updated': 1748123448673,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025kcya',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025kcya&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 50,
#    'net': 'tx',
#    'code': '2025kcya',
#    'ids': ',tx2025kcya,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 40,
#    'dmin': 0,
#    'rms': 0.3,
#    'gap': 42,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 37 km NNW of Toyah, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-103.984, 31.611, 4.4241]},
#   'id': 'tx2025kcya'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.4,
#    'place': '82 km SSE of Faya-Largeau, Chad',
#    'time': 1748121839591,
#    'updated': 1748126993040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000q1b1',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000q1b1&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 298,
#    'net': 'us',
#    'code': '7000q1b1',
#    'ids': ',us7000q1b1,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 54,
#    'dmin': 14.161,
#    'rms': 0.93,
#    'gap': 80,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.4 - 82 km SSE of Faya-Largeau, Chad'},
#   'geometry': {'type': 'Point', 'coordinates': [19.4039, 17.2333, 10]},
#   'id': 'us7000q1b1'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.1,
#    'place': '35 km SSE of Skwentna, Alaska',
#    'time': 1748120955395,
#    'updated': 1748121534005,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0256mhy1g3',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0256mhy1g3&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 19,
#    'net': 'ak',
#    'code': '0256mhy1g3',
#    'ids': ',ak0256mhy1g3,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.14,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 35 km SSE of Skwentna, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.1947, 61.6846, 68.2]},
#   'id': 'ak0256mhy1g3'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.2,
#    'place': '39 km SSE of Alamo, Nevada',
#    'time': 1748120895558,
#    'updated': 1748121094054,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00897947',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00897947&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 22,
#    'net': 'nn',
#    'code': '00897947',
#    'ids': ',nn00897947,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 9,
#    'dmin': 0.833,
#    'rms': 0.4398,
#    'gap': 322.98,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 39 km SSE of Alamo, Nevada'},
#   'geometry': {'type': 'Point', 'coordinates': [-114.9305, 37.0579, 15.1]},
#   'id': 'nn00897947'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.76,
#    'place': '9 km NW of The Geysers, CA',
#    'time': 1748120871560,
#    'updated': 1748122936890,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75186036',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75186036&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 9,
#    'net': 'nc',
#    'code': '75186036',
#    'ids': ',nc75186036,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 8,
#    'dmin': 0.006888,
#    'rms': 0.02,
#    'gap': 151,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 9 km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.84383392334, 38.8235015869141, 1.62000000476837]},
#   'id': 'nc75186036'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.6,
#    'place': '15 km SSW of Snyder, Texas',
#    'time': 1748120422274,
#    'updated': 1748120522394,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025kcwn',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025kcwn&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'tx',
#    'code': '2025kcwn',
#    'ids': ',tx2025kcwn,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 4,
#    'dmin': 0.2,
#    'rms': 0.7,
#    'gap': 177,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 15 km SSW of Snyder, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-100.954, 32.581, 5]},
#   'id': 'tx2025kcwn'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.71,
#    'place': '8 km NNW of The Geysers, CA',
#    'time': 1748119654870,
#    'updated': 1748121736752,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75186026',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75186026&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 8,
#    'net': 'nc',
#    'code': '75186026',
#    'ids': ',nc75186026,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 12,
#    'dmin': 0.01144,
#    'rms': 0.01,
#    'gap': 82,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.7 - 8 km NNW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.818664550781, 38.8326683044434, 1.76999998092651]},
#   'id': 'nc75186026'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.6,
#    'place': '49 km W of Rachel, Nevada',
#    'time': 1748119487154,
#    'updated': 1748119637157,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00897944',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00897944&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'nn',
#    'code': '00897944',
#    'ids': ',nn00897944,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 21,
#    'dmin': 0.41,
#    'rms': 0.2925,
#    'gap': 172.07,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 49 km W of Rachel, Nevada'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.3071, 37.6203, 3.3]},
#   'id': 'nn00897944'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.89,
#    'place': '21 km ESE of Anza, CA',
#    'time': 1748119487130,
#    'updated': 1748119695149,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40975167',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40975167&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 12,
#    'net': 'ci',
#    'code': '40975167',
#    'ids': ',ci40975167,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 34,
#    'dmin': 0.1253,
#    'rms': 0.18,
#    'gap': 42,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 21 km ESE of Anza, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.4533333, 33.51, 4.11]},
#   'id': 'ci40975167'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.7,
#    'place': '39 km NNW of Toyah, Texas',
#    'time': 1748117906982,
#    'updated': 1748118086959,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025kcvd',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025kcvd&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 44,
#    'net': 'tx',
#    'code': '2025kcvd',
#    'ids': ',tx2025kcvd,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 34,
#    'dmin': 0,
#    'rms': 0.4,
#    'gap': 37,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 39 km NNW of Toyah, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-104.005, 31.619, 6.6663]},
#   'id': 'tx2025kcvd'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.37,
#    'place': '5 km NE of Westmorland, CA',
#    'time': 1748117033770,
#    'updated': 1748117242803,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40975143',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40975143&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 29,
#    'net': 'ci',
#    'code': '40975143',
#    'ids': ',ci40975143,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 28,
#    'dmin': 0.03192,
#    'rms': 0.28,
#    'gap': 51,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 5 km NE of Westmorland, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.5788333, 33.0701667, 9.95]},
#   'id': 'ci40975143'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.3,
#    'place': 'Banda Sea',
#    'time': 1748115779237,
#    'updated': 1748118192040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000q1ax',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000q1ax&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 284,
#    'net': 'us',
#    'code': '7000q1ax',
#    'ids': ',us7000q1ax,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 34,
#    'dmin': 4.404,
#    'rms': 0.57,
#    'gap': 86,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.3 - Banda Sea'},
#   'geometry': {'type': 'Point', 'coordinates': [129.8251, -6.6264, 162.116]},
#   'id': 'us7000q1ax'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.99,
#    'place': '0 km NNE of The Geysers, CA',
#    'time': 1748115225820,
#    'updated': 1748117538268,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75186011',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75186011&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 15,
#    'net': 'nc',
#    'code': '75186011',
#    'ids': ',nc75186011,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 12,
#    'dmin': 0.01263,
#    'rms': 0.03,
#    'gap': 71,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 0 km NNE of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.756332397461, 38.7809982299805, 1.51999998092651]},
#   'id': 'nc75186011'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.64,
#    'place': '10 km NW of Avenal, CA',
#    'time': 1748114867000,
#    'updated': 1748130739773,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75186006',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75186006&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 6,
#    'net': 'nc',
#    'code': '75186006',
#    'ids': ',nc75186006,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 18,
#    'dmin': 0.0547,
#    'rms': 0.07,
#    'gap': 174,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.6 - 10 km NW of Avenal, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-120.216166666667, 36.0653333333333, 7.82]},
#   'id': 'nc75186006'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '18 km S of Knik River, Alaska',
#    'time': 1748114769691,
#    'updated': 1748114893700,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0256mgusyx',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0256mgusyx&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'ak',
#    'code': '0256mgusyx',
#    'ids': ',ak0256mgusyx,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 1.34,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 18 km S of Knik River, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-148.8878, 61.2914, 19.5]},
#   'id': 'ak0256mgusyx'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.91,
#    'place': '6 km WSW of Anza, CA',
#    'time': 1748114714610,
#    'updated': 1748114928057,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40975111',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40975111&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 13,
#    'net': 'ci',
#    'code': '40975111',
#    'ids': ',ci40975111,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 29,
#    'dmin': 0.03831,
#    'rms': 0.14,
#    'gap': 40,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 6 km WSW of Anza, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.7311667, 33.5273333, 5.93]},
#   'id': 'ci40975111'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.95,
#    'place': '1 km NNW of The Geysers, CA',
#    'time': 1748114706740,
#    'updated': 1748117239239,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75186001',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75186001&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 14,
#    'net': 'nc',
#    'code': '75186001',
#    'ids': ',nc75186001,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 11,
#    'dmin': 0.01806,
#    'rms': 0.03,
#    'gap': 81,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 1 km NNW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.759834289551, 38.7830009460449, 1.9099999666214]},
#   'id': 'nc75186001'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.1,
#    'place': '7 km ENE of Fox, Alaska',
#    'time': 1748113513516,
#    'updated': 1748113628581,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0256mgqb87',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0256mgqb87&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 19,
#    'net': 'ak',
#    'code': '0256mgqb87',
#    'ids': ',ak0256mgqb87,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.76,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 7 km ENE of Fox, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-147.4816, 64.9914, 0]},
#   'id': 'ak0256mgqb87'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.66,
#    'place': '5 km WSW of Anza, CA',
#    'time': 1748113167880,
#    'updated': 1748113375952,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40975095',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40975095&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 7,
#    'net': 'ci',
#    'code': '40975095',
#    'ids': ',ci40975095,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 17,
#    'dmin': 0.03393,
#    'rms': 0.11,
#    'gap': 69,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.7 - 5 km WSW of Anza, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.7226667, 33.5336667, 5.76]},
#   'id': 'ci40975095'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.92,
#    'place': '3 km ESE of Lopez Point, CA',
#    'time': 1748113115120,
#    'updated': 1748120839658,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185991',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185991&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 57,
#    'net': 'nc',
#    'code': '75185991',
#    'ids': ',nc75185991,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 21,
#    'dmin': 0.06077,
#    'rms': 0.07,
#    'gap': 197,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 3 km ESE of Lopez Point, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.538833618164, 36.0123329162598, 6.26000022888184]},
#   'id': 'nc75185991'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.28,
#    'place': '4 km SSE of Alger, Washington',
#    'time': 1748113053930,
#    'updated': 1748149264810,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw62115261',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw62115261&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 25,
#    'net': 'uw',
#    'code': '62115261',
#    'ids': ',uw62115261,',
#    'sources': ',uw,',
#    'types': ',origin,phase-data,',
#    'nst': 14,
#    'dmin': 0.06921,
#    'rms': 0.1,
#    'gap': 131,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 4 km SSE of Alger, Washington'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.3295, 48.58166666666666, 16.15]},
#   'id': 'uw62115261'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.74,
#    'place': '6 km NNW of The Geysers, CA',
#    'time': 1748112917190,
#    'updated': 1748115740065,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185986',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185986&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 8,
#    'net': 'nc',
#    'code': '75185986',
#    'ids': ',nc75185986,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 10,
#    'dmin': 0.01224,
#    'rms': 0.02,
#    'gap': 85,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.7 - 6 km NNW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.796333312988, 38.8175010681152, 2.39000010490417]},
#   'id': 'nc75185986'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.27,
#    'place': '10 km NW of The Geysers, CA',
#    'time': 1748112556840,
#    'updated': 1748119336483,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185981',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185981&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 25,
#    'net': 'nc',
#    'code': '75185981',
#    'ids': ',nc75185981,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 25,
#    'dmin': 0.0008537,
#    'rms': 0.02,
#    'gap': 78,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 10 km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.835998535156, 38.837833404541, 1.77999997138977]},
#   'id': 'nc75185981'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.1,
#    'place': '20 km NNE of Yerington, Nevada',
#    'time': 1748111709720,
#    'updated': 1748111843113,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00897939',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nn00897939&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 19,
#    'net': 'nn',
#    'code': '00897939',
#    'ids': ',nn00897939,',
#    'sources': ',nn,',
#    'types': ',origin,phase-data,',
#    'nst': 10,
#    'dmin': 0.026,
#    'rms': 0.0946,
#    'gap': 119,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 20 km NNE of Yerington, Nevada'},
#   'geometry': {'type': 'Point', 'coordinates': [-119.0507, 39.1445, 6.8]},
#   'id': 'nn00897939'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.46,
#    'place': '16 km NNW of Stanley, Idaho',
#    'time': 1748111462730,
#    'updated': 1748178728120,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/mb90089133',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=mb90089133&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 33,
#    'net': 'mb',
#    'code': '90089133',
#    'ids': ',mb90089133,',
#    'sources': ',mb,',
#    'types': ',origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.2745,
#    'rms': 0.12,
#    'gap': 77,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 16 km NNW of Stanley, Idaho'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.035166666667, 44.345, 3.89]},
#   'id': 'mb90089133'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.51,
#    'place': '5 km NE of Windsor, CA',
#    'time': 1748111246650,
#    'updated': 1748132836015,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185976',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185976&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 35,
#    'net': 'nc',
#    'code': '75185976',
#    'ids': ',nc75185976,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 65,
#    'dmin': 0.066,
#    'rms': 0.09,
#    'gap': 42,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 5 km NE of Windsor, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.785666666667, 38.5873333333333, 7.24]},
#   'id': 'nc75185976'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.61,
#    'place': '6 km WNW of Dunnigan, CA',
#    'time': 1748110835390,
#    'updated': 1748116338136,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185971',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185971&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 40,
#    'net': 'nc',
#    'code': '75185971',
#    'ids': ',nc75185971,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 5,
#    'dmin': 0.1645,
#    'rms': 0.04,
#    'gap': 189,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 6 km WNW of Dunnigan, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.040832519531, 38.90283203125, 2.14000010490417]},
#   'id': 'nc75185971'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.28,
#    'place': '5 km WNW of Dunnigan, CA',
#    'time': 1748110689460,
#    'updated': 1748131640870,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185966',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185966&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 80,
#    'net': 'nc',
#    'code': '75185966',
#    'ids': ',nc75185966,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 52,
#    'dmin': 0.1504,
#    'rms': 0.24,
#    'gap': 31,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 5 km WNW of Dunnigan, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.0225, 38.8948333333333, 15.29]},
#   'id': 'nc75185966'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.71,
#    'place': '8 km WNW of Cobb, CA',
#    'time': 1748110599130,
#    'updated': 1748112139814,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185961',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185961&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 8,
#    'net': 'nc',
#    'code': '75185961',
#    'ids': ',nc75185961,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 12,
#    'dmin': 0.01176,
#    'rms': 0.04,
#    'gap': 57,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.7 - 8 km WNW of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.813667297363, 38.8348350524902, 4.63000011444092]},
#   'id': 'nc75185961'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.03,
#    'place': '3 km W of Cobb, CA',
#    'time': 1748110489470,
#    'updated': 1748111537636,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185956',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185956&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 16,
#    'net': 'nc',
#    'code': '75185956',
#    'ids': ',nc75185956,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 16,
#    'dmin': 0.01536,
#    'rms': 0.04,
#    'gap': 117,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 3 km W of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.759330749512, 38.8160018920898, 1.62000000476837]},
#   'id': 'nc75185956'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.45,
#    'place': '7 km NNW of Pinnacles, CA',
#    'time': 1748109693920,
#    'updated': 1748153730152,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185951',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185951&format=geojson',
#    'felt': 2,
#    'cdi': 3.3,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 93,
#    'net': 'nc',
#    'code': '75185951',
#    'ids': ',nc75185951,',
#    'sources': ',nc,',
#    'types': ',dyfi,focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 49,
#    'dmin': 0.0133,
#    'rms': 0.13,
#    'gap': 67,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 7 km NNW of Pinnacles, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.19066619873, 36.5843315124512, 4.21999979019165]},
#   'id': 'nc75185951'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.1,
#    'place': '50 km ENE of Ouzinkie, Alaska',
#    'time': 1748109661872,
#    'updated': 1748109806366,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0256mg3zuz',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0256mg3zuz&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 68,
#    'net': 'ak',
#    'code': '0256mg3zuz',
#    'ids': ',ak0256mg3zuz,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.16,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.1 - 50 km ENE of Ouzinkie, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.7687, 58.1592, 26.6]},
#   'id': 'ak0256mg3zuz'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.55,
#    'place': '33 km W of Petrolia, CA',
#    'time': 1748109492950,
#    'updated': 1748130440739,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185946',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185946&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 100,
#    'net': 'nc',
#    'code': '75185946',
#    'ids': ',nc75185946,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 66,
#    'dmin': 0.2732,
#    'rms': 0.28,
#    'gap': 245,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.6 - 33 km W of Petrolia, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-124.675333333333, 40.3203333333333, 9.89]},
#   'id': 'nc75185946'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.58,
#    'place': '6 km S of Huntington Beach, CA',
#    'time': 1748108910610,
#    'updated': 1748109552660,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40975055',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40975055&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 38,
#    'net': 'ci',
#    'code': '40975055',
#    'ids': ',ci40975055,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 40,
#    'dmin': 0.06332,
#    'rms': 0.23,
#    'gap': 119,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 6 km S of Huntington Beach, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-118.0043333, 33.6361667, 15.21]},
#   'id': 'ci40975055'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.58,
#    'place': '24 km N of Ridgecrest, CA',
#    'time': 1748108428630,
#    'updated': 1748108634522,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40975031',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40975031&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 5,
#    'net': 'ci',
#    'code': '40975031',
#    'ids': ',ci40975031,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 13,
#    'dmin': 0.08224,
#    'rms': 0.1,
#    'gap': 121,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.6 - 24 km N of Ridgecrest, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.6685, 35.8336667, 9.09]},
#   'id': 'ci40975031'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.28,
#    'place': '10 km NW of The Geysers, CA',
#    'time': 1748107843290,
#    'updated': 1748110038485,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185941',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185941&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 1,
#    'net': 'nc',
#    'code': '75185941',
#    'ids': ',nc75185941,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 8,
#    'dmin': 0.003822,
#    'rms': 0.01,
#    'gap': 130,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.3 - 10 km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.852165222168, 38.8264999389648, 2.58999991416931]},
#   'id': 'nc75185941'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.64,
#    'place': '20 km SW of La Quinta, CA',
#    'time': 1748107693030,
#    'updated': 1748107900413,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40975023',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40975023&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 6,
#    'net': 'ci',
#    'code': '40975023',
#    'ids': ',ci40975023,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 8,
#    'dmin': 0.1286,
#    'rms': 0.09,
#    'gap': 179,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.6 - 20 km SW of La Quinta, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.4536667, 33.5285, 2.47]},
#   'id': 'ci40975023'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.96,
#    'place': '3 km SE of The Geysers, CA',
#    'time': 1748107573180,
#    'updated': 1748109137383,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185936',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185936&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 14,
#    'net': 'nc',
#    'code': '75185936',
#    'ids': ',nc75185936,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 10,
#    'dmin': 0.004124,
#    'rms': 0.03,
#    'gap': 112,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 3 km SE of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.726501464844, 38.7576675415039, 2.35999989509583]},
#   'id': 'nc75185936'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.87,
#    'place': '24 km N of Ridgecrest, CA',
#    'time': 1748107288480,
#    'updated': 1748107497487,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40975007',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40975007&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 12,
#    'net': 'ci',
#    'code': '40975007',
#    'ids': ',ci40975007,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 21,
#    'dmin': 0.0799,
#    'rms': 0.15,
#    'gap': 48,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 24 km N of Ridgecrest, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.671, 35.8323333, 7.92]},
#   'id': 'ci40975007'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.9,
#    'place': 'State of Chuuk, Federated States of Micronesia',
#    'time': 1748105160148,
#    'updated': 1748106631040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us7000q1aj',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us7000q1aj&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 369,
#    'net': 'us',
#    'code': '7000q1aj',
#    'ids': ',us7000q1aj,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 43,
#    'dmin': 3.819,
#    'rms': 0.73,
#    'gap': 74,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.9 - State of Chuuk, Federated States of Micronesia'},
#   'geometry': {'type': 'Point', 'coordinates': [148.0711, 6.7655, 10]},
#   'id': 'us7000q1aj'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.34,
#    'place': '21 km E of Julian, CA',
#    'time': 1748104904150,
#    'updated': 1748105546360,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40974863',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40974863&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 84,
#    'net': 'ci',
#    'code': '40974863',
#    'ids': ',ci40974863,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 90,
#    'dmin': 0.05258,
#    'rms': 0.23,
#    'gap': 28,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.3 - 21 km E of Julian, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.3818333, 33.0543333, 13.61]},
#   'id': 'ci40974863'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.21,
#    'place': '6 km WSW of Anza, CA',
#    'time': 1748104122080,
#    'updated': 1748104779960,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40974855',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40974855&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 23,
#    'net': 'ci',
#    'code': '40974855',
#    'ids': ',ci40974855,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 50,
#    'dmin': 0.0388,
#    'rms': 0.17,
#    'gap': 33,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 6 km WSW of Anza, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.733, 33.5266667, 4.76]},
#   'id': 'ci40974855'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.23,
#    'place': '9 km NW of The Geysers, CA',
#    'time': 1748104017330,
#    'updated': 1748118439377,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185921',
# ...
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 8,
#    'dmin': 0.0131,
#    'rms': 0.01,
#    'gap': 89,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.4 - 8 km NNW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.818664550781, 38.8346672058105, 1.86000001430511]},
#   'id': 'nc75185696'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.76,
#    'place': '8 km NW of The Geysers, CA',
#    'time': 1748051704430,
#    'updated': 1748055438519,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185691',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185691&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 9,
#    'net': 'nc',
#    'code': '75185691',
#    'ids': ',nc75185691,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 7,
#    'dmin': 0.006192,
#    'rms': 0.01,
#    'gap': 137,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 8 km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.832496643066, 38.8144989013672, 1.46000003814697]},
#   'id': 'nc75185691'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.78,
#    'place': '8 km NNW of The Geysers, CA',
#    'time': 1748051653580,
#    'updated': 1748054238377,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185686',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185686&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 9,
#    'net': 'nc',
#    'code': '75185686',
#    'ids': ',nc75185686,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 14,
#    'dmin': 0.01291,
#    'rms': 0.01,
#    'gap': 87,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 8 km NNW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.818168640137, 38.8346672058105, 1.76999998092651]},
#   'id': 'nc75185686'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.83,
#    'place': '17 km ESE of Anza, CA',
#    'time': 1748050018090,
#    'updated': 1748074132606,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40974199',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40974199&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 11,
#    'net': 'ci',
#    'code': '40974199',
#    'ids': ',ci40974199,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 29,
#    'dmin': 0.07868,
#    'rms': 0.16,
#    'gap': 58,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 17 km ESE of Anza, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.5081667, 33.4986667, 11.66]},
#   'id': 'ci40974199'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.06,
#    'place': '6 km WSW of Corona, CA',
#    'time': 1748049712920,
#    'updated': 1748073817303,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40974191',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40974191&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 17,
#    'net': 'ci',
#    'code': '40974191',
#    'ids': ',ci40974191,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 24,
#    'dmin': 0.05172,
#    'rms': 0.13,
#    'gap': 103,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 6 km WSW of Corona, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.6286667, 33.8445, 9.52]},
#   'id': 'ci40974191'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '41 km NNW of Beluga, Alaska',
#    'time': 1748049569664,
#    'updated': 1748049689532,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0256m63jly',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0256m63jly&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'ak',
#    'code': '0256m63jly',
#    'ids': ',ak0256m63jly,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.46,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 41 km NNW of Beluga, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.4735, 61.4601, 63]},
#   'id': 'ak0256m63jly'},
#  {'type': 'Feature',
#   'properties': {'mag': 1,
#    'place': '7 km WNW of Cobb, CA',
#    'time': 1748048770400,
#    'updated': 1748052739218,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185681',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185681&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 15,
#    'net': 'nc',
#    'code': '75185681',
#    'ids': ',nc75185681,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 22,
#    'dmin': 0.00921,
#    'rms': 0.02,
#    'gap': 61,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 7 km WNW of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.801834106445, 38.8363342285156, 1.96000003814697]},
#   'id': 'nc75185681'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.37,
#    'place': '43 km W of Chignik Lake, Alaska',
#    'time': 1748048260320,
#    'updated': 1748148362320,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av93042614',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av93042614&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 2,
#    'net': 'av',
#    'code': '93042614',
#    'ids': ',av93042614,',
#    'sources': ',av,',
#    'types': ',origin,phase-data,',
#    'nst': 4,
#    'dmin': 0.09857,
#    'rms': 0.24,
#    'gap': 287,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.4 - 43 km W of Chignik Lake, Alaska'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-159.459166666667, 56.2991666666667, 4.07]},
#   'id': 'av93042614'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.9,
#    'place': '27 km E of Clear, Alaska',
#    'time': 1748048256508,
#    'updated': 1748048378062,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0256m5q9qq',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0256m5q9qq&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 12,
#    'net': 'ak',
#    'code': '0256m5q9qq',
#    'ids': ',ak0256m5q9qq,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.65,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 27 km E of Clear, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-148.6264, 64.2597, 11.5]},
#   'id': 'ak0256m5q9qq'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '5 km S of Funny River, Alaska',
#    'time': 1748048035494,
#    'updated': 1748048156237,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0256m5pgcd',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0256m5pgcd&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'ak',
#    'code': '0256m5pgcd',
#    'ids': ',ak0256m5pgcd,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.52,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 5 km S of Funny River, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-150.7739, 60.4516, 26.8]},
#   'id': 'ak0256m5pgcd'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.77,
#    'place': '1 km E of Mariano Colón, Puerto Rico',
#    'time': 1748047698770,
#    'updated': 1748048523980,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71483438',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71483438&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 48,
#    'net': 'pr',
#    'code': '71483438',
#    'ids': ',pr71483438,',
#    'sources': ',pr,',
#    'types': ',origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.0765,
#    'rms': 0.21,
#    'gap': 170,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 1 km E of Mariano Colón, Puerto Rico'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-66.3145, 18.0208333333333, 13.28]},
#   'id': 'pr71483438'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.7,
#    'place': '37 km WSW of Mentone, Texas',
#    'time': 1748047660360,
#    'updated': 1748047953664,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025kbim',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025kbim&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 44,
#    'net': 'tx',
#    'code': '2025kbim',
#    'ids': ',tx2025kbim,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 39,
#    'dmin': 0,
#    'rms': 0.5,
#    'gap': 40,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 37 km WSW of Mentone, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-103.986, 31.618, 6.5398]},
#   'id': 'tx2025kbim'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.81,
#    'place': '62 km WNW of Tyonek, Alaska',
#    'time': 1748047134970,
#    'updated': 1748147920280,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av93042609',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av93042609&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'av',
#    'code': '93042609',
#    'ids': ',av93042609,',
#    'sources': ',av,',
#    'types': ',origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.02915,
#    'rms': 0.31,
#    'gap': 111,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M -0.8 - 62 km WNW of Tyonek, Alaska'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-152.239666666667, 61.2348333333333, -2.53]},
#   'id': 'av93042609'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.36,
#    'place': '6 km NNW of The Geysers, CA',
#    'time': 1748046997950,
#    'updated': 1748051240047,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75185676',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75185676&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 28,
#    'net': 'nc',
#    'code': '75185676',
#    'ids': ',nc75185676,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 31,
#    'dmin': 0.009569,
#    'rms': 0.02,
#    'gap': 33,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 6 km NNW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.797996520996, 38.8250007629395, 2.10999989509583]},
#   'id': 'nc75185676'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.8,
#    'place': '13 km SSE of Fern Forest, Hawaii',
#    'time': 1748046763790,
#    'updated': 1748049308070,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv74679312',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=hv74679312&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 50,
#    'net': 'hv',
#    'code': '74679312',
#    'ids': ',hv74679312,',
#    'sources': ',hv,',
#    'types': ',origin,phase-data,',
#    'nst': 36,
#    'dmin': 0.04309,
#    'rms': 0.14,
#    'gap': 131,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 13 km SSE of Fern Forest, Hawaii'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-155.098333333333, 19.35, 5.86]},
#   'id': 'hv74679312'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.9,
#    'place': '44 km W of Salamatof, Alaska',
#    'time': 1748046417763,
#    'updated': 1748046548808,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0256m5jo6o',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0256m5jo6o&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 12,
#    'net': 'ak',
#    'code': '0256m5jo6o',
#    'ids': ',ak0256m5jo6o,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.47,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 44 km W of Salamatof, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-152.1262, 60.6724, 81.2]},
#   'id': 'ak0256m5jo6o'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.78,
#    'place': '63 km WNW of Tyonek, Alaska',
#    'time': 1748045607540,
#    'updated': 1748133525400,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av93042604',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av93042604&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'av',
#    'code': '93042604',
#    'ids': ',av93042604,',
#    'sources': ',av,',
#    'types': ',origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.04134,
#    'rms': 0.11,
#    'gap': 148,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M -0.8 - 63 km WNW of Tyonek, Alaska'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-152.238166666667, 61.2751666666667, 3.55]},
#   'id': 'av93042604'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.8,
#    'place': '20 km WNW of Petersville, Alaska',
#    'time': 1748045486169,
#    'updated': 1748045641314,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0256m5ge08',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0256m5ge08&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 50,
#    'net': 'ak',
#    'code': '0256m5ge08',
#    'ids': ',ak0256m5ge08,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.58,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 20 km WNW of Petersville, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.1477, 62.5332, 60.6]},
#   'id': 'ak0256m5ge08'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.31,
#    'place': '6 km SSW of Salton City, CA',
#    'time': 1748045299670,
#    'updated': 1748045830405,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci40974183',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci40974183&format=geojson',
#    'felt': 1,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 27,
#    'net': 'ci',
#    'code': '40974183',
#    'ids': ',ci40974183,',
#    'sources': ',ci,',
#    'types': ',dyfi,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 36,
#    'dmin': 0.1801,
#    'rms': 0.25,
#    'gap': 152,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 6 km SSW of Salton City, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-115.9883333, 33.2548333, 3.71]},
#   'id': 'ci40974183'}]
